# %% [markdown]
# # Modular Arithmetic

# %% [markdown]
# ## GCD

# %%
a, b = 66528, 52920
gcd(a, b)
# Out:
# 1512

# %% [markdown]
# ## Extended GCD

# %%
p, q = 26513, 32321
xgcd(p, q)
# Out:
# (1, 10245, -8404)

# %% [markdown]
# ## Modular Arithmetic 1

# %%
min(11 % 6, 8146798528947 % 17)
# Out:
# 4

# %% [markdown]
# ## Modular Arithmetic 2

# %%
## a^(p - 1) = 1 mod p for prime p
1
# Out:
# 1

# %% [markdown]
# ## Modular Inverting

# %%
## 3 * 9 = 1 mod 13
9
# Out:
# 9
