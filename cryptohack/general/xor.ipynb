# %% [markdown]
# # XOR

# %% [markdown]
# ## XOR Starter

# %%
from pwn import *

xor(b'label', int(13))
# Out:
# b'aloha'

# %% [markdown]
# ## XOR Properties

# %%
from pwn import *

k1 = bytes.fromhex('a6c8b6733c9b22de7bc0253266a3867df55acde8635e19c73313')
k2 = xor(k1, bytes.fromhex('37dcb292030faa90d07eec17e3b1c6d8daf94c35d4c9191a5e1e'))
k3 = xor(k2, bytes.fromhex('c1545756687e7573db23aa1c3452a098b71a7fbf0fddddde5fc1'))
flag = xor(k1, k2, k3, bytes.fromhex('04ee9855208a2cd59091d04767ae47963170d1660df7f56f5faf'))
print(flag)
# Out:
# b'crypto{x0r_i5_ass0c1at1v3}'

# %% [markdown]
# ## Favorite byte

# %%
enc = bytes.fromhex('73626960647f6b206821204f21254f7d694f7624662065622127234f726927756d')

for i in range(256):
    if str(xor(enc, i)).startswith('b\'crypto'):
        print(xor(enc, i))
        break
# Out:
# b'crypto{0x10_15_my_f4v0ur173_by7e}'

# %% [markdown]
# ## You either know, XOR you don't

# %%
enc = bytes.fromhex('0e0b213f26041e480b26217f27342e175d0e070a3c5b103e2526217f27342e175d0e077e263451150104')

xor(enc, b'myXORkey')
# Out:
# b'crypto{1f_y0u_Kn0w_En0uGH_y0u_Kn0w_1t_4ll}'

# %% [markdown]
# ## Lemur XOR

# %%
# %%capture
from pwn import *
from PIL import Image, ImageChops

lemur_url = 'https://cryptohack.org/static/challenges/lemur_ed66878c338e662d3473f0d98eedbd0d.png'
flag_url = 'https://cryptohack.org/static/challenges/flag_7ae18c704272532658c10b5faad06d74.png'
wget(lemur_url, 'lemur.png')
wget(flag_url, 'flag.png')
# Out:
# [x] Downloading 'https://cryptohack.org/static/challenges/lemur_ed66878c338e662d3473f0d98eedbd0d.png'
# [x] Downloading 'https://cryptohack.org/static/challenges/lemur_ed66878c338e662d3473f0d98eedbd0d.png': Making request...
# [x] Downloading 'https://cryptohack.org/static/challenges/lemur_ed66878c338e662d3473f0d98eedbd0d.png': 0 / 558.78KB
# [x] Downloading 'https://cryptohack.org/static/challenges/lemur_ed66878c338e662d3473f0d98eedbd0d.png': 32.00KB / 558.78KB
# [x] Downloading 'https://cryptohack.org/static/challenges/lemur_ed66878c338e662d3473f0d98eedbd0d.png': 96.00KB / 558.78KB
# [x] Downloading 'https://cryptohack.org/static/challenges/lemur_ed66878c338e662d3473f0d98eedbd0d.png': 208.00KB / 558.78KB
# [x] Downloading 'https://cryptohack.org/static/challenges/lemur_ed66878c338e662d3473f0d98eedbd0d.png': 416.00KB / 558.78KB
# [+] Downloading 'https://cryptohack.org/static/challenges/lemur_ed66878c338e662d3473f0d98eedbd0d.png': Saved 'lemur.png' (558.78KB)
# [x] Downloading 'https://cryptohack.org/static/challenges/flag_7ae18c704272532658c10b5faad06d74.png'
# [x] Downloading 'https://cryptohack.org/static/challenges/flag_7ae18c704272532658c10b5faad06d74.png': Making request...
# [x] Downloading 'https://cryptohack.org/static/challenges/flag_7ae18c704272532658c10b5faad06d74.png': 0 / 558.78KB
# [x] Downloading 'https://cryptohack.org/static/challenges/flag_7ae18c704272532658c10b5faad06d74.png': 32.00KB / 558.78KB
# [x] Downloading 'https://cryptohack.org/static/challenges/flag_7ae18c704272532658c10b5faad06d74.png': 96.00KB / 558.78KB
# [x] Downloading 'https://cryptohack.org/static/challenges/flag_7ae18c704272532658c10b5faad06d74.png': 208.00KB / 558.78KB
# [x] Downloading 'https://cryptohack.org/static/challenges/flag_7ae18c704272532658c10b5faad06d74.png': 432.00KB / 558.78KB
# [+] Downloading 'https://cryptohack.org/static/challenges/flag_7ae18c704272532658c10b5faad06d74.png': Saved 'flag.png' (558.78KB)

# %%
lemur = Image.open('lemur.png')
flag = Image.open('flag.png')

ImageChops.difference(lemur, flag)
# Out:
# <PIL.Image.Image image mode=RGB size=582x327 at 0x7F57627A73C8>
