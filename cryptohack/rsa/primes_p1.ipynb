# %% [markdown]
# # Primes part I
#
# If $\varphi$ can be derived easily, the encryption can be easily broken.

# %%
from sage.all import *
from Crypto.Util.number import *

# %% [markdown]
# ## Factoring

# %%
min(factor(510143758735509025530880200653196460532653147))
# Out:
# (19704762736204164635843, 1)

# %% [markdown]
# ## Inferius Prime

# %%
n = 742449129124467073921545687640895127535705902454369756401331
e = 3
ct = 39207274348578481322317340648475596807303160111338236677373

R = Integers(n)
pt = R(ct).nth_root(e)
long_to_bytes(int(pt))
# Out:
# b'crypto{N33d_b1g_pR1m35}'

# %% [markdown]
# ## Monoprime

# %%
n =                                                                   
e = 65537
ct = 

d = pow(e, -1, n - 1)
pt = pow(ct, d, n)
long_to_bytes(pt)
# Out:
# b'crypto{0n3_pr1m3_41n7_pr1m3_l0l}'

# %% [markdown]
# # Square Eyes

# %%
N = ...
e = 65537
c = ...

d = pow(e, -1, N * (N - 1))
pt = pow(c, d, N)
long_to_bytes(pt)
# Out:
# b'crypto{squar3_r00t_i5_f4st3r_th4n_f4ct0r1ng!}'

# %% [markdown]
# ## Manyprime
#
# So many small primes in the modulus ? Use Elliptic Curve!

# %%
n = ...
e = 65537
ct = ...

pf = ecm.factor(n)
phi = prod([p - 1 for p in pf])
d = pow(e, -1, phi)
pt = pow(ct, d, n)
long_to_bytes(pt)
# Out:
# b'crypto{700_m4ny_5m4ll_f4c70r5}'
