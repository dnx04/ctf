# %% [markdown]
# # JSON Web Tokens

# %% [markdown]
# ## Token Appreciation

# %%
import jwt
# Out:
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-2-3638fb7ff429> in <module>()
# ----> 1 import jwt
#
# ModuleNotFoundError: No module named 'jwt'
