# %% [markdown]
# # Introduction to CryptoHack

# %% [markdown]
# # [ASCII](https://cryptohack.org/courses/intro/enc1/)

# %%
enc = [99, 114, 121, 112, 116, 111, 123, 65, 83, 67, 73, 73, 95, 112, 114, 49, 110, 116, 52, 98, 108, 51, 125]
''.join([chr(i) for i in enc])
# Out:
# 'crypto{ASCII_pr1nt4bl3}'

# %% [markdown]
# # [Hex](https://cryptohack.org/courses/intro/enc2/)

# %%
enc = '63727970746f7b596f755f77696c6c5f62655f776f726b696e675f776974685f6865785f737472696e67735f615f6c6f747d'
bytes.fromhex(enc)
# Out:
# b'crypto{You_will_be_working_with_hex_strings_a_lot}'

# %% [markdown]
# # [Base64](https://cryptohack.org/courses/intro/enc3/)

# %%
import base64

enc = '72bca9b68fc16ac7beeb8f849dca1d8a783e8acf9679bf9269f7bf'
base64.b64encode(bytes.fromhex(enc))
# Out:
# b'crypto/Base+64+Encoding+is+Web+Safe/'

# %% [markdown]
# # [Bytes and Big Integers](https://cryptohack.org/courses/intro/enc4/)

# %%
from Crypto.Util.number import *

enc = 11515195063862318899931685488813747395775516287289682636499965282714637259206269
long_to_bytes(enc)
# Out:
# b'crypto{3nc0d1n6_4ll_7h3_w4y_d0wn}'

# %% [markdown]
# # [XOR Starter](https://cryptohack.org/courses/intro/enc5/)

# %%
from pwn import *

xor(b'label', 13)
# Out:
# b'aloha'

# %% [markdown]
# # [XOR Properties](https://cryptohack.org/courses/intro/xor1/)

# %%
k1 = bytes.fromhex('a6c8b6733c9b22de7bc0253266a3867df55acde8635e19c73313')
k2 = xor(k1, bytes.fromhex('37dcb292030faa90d07eec17e3b1c6d8daf94c35d4c9191a5e1e'))
k3 = xor(k2, bytes.fromhex('c1545756687e7573db23aa1c3452a098b71a7fbf0fddddde5fc1'))
flag = xor(k1, k2, k3, bytes.fromhex('04ee9855208a2cd59091d04767ae47963170d1660df7f56f5faf'))
print(flag)
# Out:
# b'crypto{x0r_i5_ass0c1at1v3}'

# %% [markdown]
# # [Favorite byte](https://cryptohack.org/courses/intro/xorkey0/)

# %%
enc = bytes.fromhex('73626960647f6b206821204f21254f7d694f7624662065622127234f726927756d')

for i in range(256):
    if str(xor(enc, i)).startswith('b\'crypto'):
        print(xor(enc, i))
        break
# Out:
# b'crypto{0x10_15_my_f4v0ur173_by7e}'

# %% [markdown]
# # [You either know, XOR you don't](https://cryptohack.org/courses/intro/xorkey1/)

# %%
enc = bytes.fromhex('0e0b213f26041e480b26217f27342e175d0e070a3c5b103e2526217f27342e175d0e077e263451150104')

xor(enc, b'myXORkey')
# Out:
# b'crypto{1f_y0u_Kn0w_En0uGH_y0u_Kn0w_1t_4ll}'
